# %% [markdown]
# ## Jupyter notebook illustrating routines for processing HDP-SLDS segmented trajectory data for MLE on segments
# ### create segmented data via something like "pullCPdataAndSave2019.m" after HDP-SLDS run on rull trajectory)
#
# Copyright 2018 Ursa Analytics, Inc.
# Licensed under the Apache License, Version 2.0 (the "License");
# You may obtain a copy of the License at http://www.apache.org/licenses/LICENSE-2.0

# %%
# %matplotlib inline 
import matplotlib.font_manager as font_manager
import matplotlib.pyplot as plt
import numpy as np
import commands,glob2,os
import re,h5py

# %%
#define aux functions
def rle(inarray):
    """ run length encoding.  
        Multi datatype arrays catered for including non Numpy
        returns: tuple (runlengths, startpositions, values) 
        
        Sample call
        >>> length,pos,val = rle([True, True, True, False, True, False, False])
        Out: length <- array([3, 1, 1, 2])
             pos    <- array([0, 3, 4, 5])
             val    <- array([ True, False,  True, False], dtype=bool)
             
        #rle helps in getting stats on sequences vs. just finding locations of changepoints
        #            can be used with arbitrary category labels
        #dumbList = ["foo", "bar", "bar","blah","blah","blah","bleh"]
        #rle(dumbList)
    """
    ia = np.asarray(inarray)                  # force numpy
    n = len(ia)
    if n == 0: 
        return (None, None, None)
    else:
        y = np.array(ia[1:] != ia[:-1])     # pairwise unequal (string safe)
        i = np.append(np.where(y), n - 1)   # must include last element posi
        z = np.diff(np.append(-1, i))       # run lengths
        p = np.cumsum(np.append(0, z))[:-1] # positions
        return(z, p, ia[i])                 # last element contains type of data in run

def loadh5(floc,dsetnameIndex=0,printFile=False,printDsets=False): #load a numeric hdf5 file. "floc" is the path of ASCII file to read.


    if floc[0]=='~':  #replace standard unix home shortcut with explicit path
        floc='/Users/calderoc' + floc[1:]
    f=h5py.File(floc,'r')
    dsetNames = f.keys()
    if printFile:
        print 'Read file: ' + floc
        print 'Pulling Dataset index', dsetnameIndex, 'Named: ' + dsetNames[dsetnameIndex]
    if printDsets:
        if printFile:
            print 'Displaying top level dsets in hdf5 file since printDset set to True'
            print 'Found N= ',len(f.keys()),'top level dsets (returning integer vs. any data since printDset=True)'
            for i in f.keys():
                print i
        return len(f.keys())
    else:
        if type(dsetnameIndex) is list: #read a batch without reading dset keys each time (costly if big data file)
            g=[]
            [g.append(f[dsetNames[dsetnameIndexi]].value) for dsetnameIndexi in dsetnameIndex]
            
        else:
            dsetname=dsetNames[dsetnameIndex]
            g= f[dsetname]  #default name for h5import dataset when no arg given (so i use this in my scripts as well)
            g= np.array(g) #return numpy array (get shape with g.shape)
    f.close()
    return g  

def wouth5(floc,DATAMAT,dset='dataset0'): #write a simple hdf5 file into "floc";  assumes numpy array passed as DATAMAT.  handling other datatypes with h5py is fairly easy
    if floc[0]=='~':  #replace standard unix home shortcut with explicit path
                floc='/Users/calderoc' + floc[1:] #purdue login: calderoc / princeton: ccaldero; since grad school i use either calderoc or ccalderoN as unix logins (keep symlink to both home folders in *nix style systems)
    f=h5py.File(floc,'a')#default name for h5import dataset when no arg given (so i use this in my scripts as well)
    dset = f.create_dataset(dset, data=DATAMAT)
    f.close()
    return 0

# %%
datadir='./*.h5' # used to run in output folder of pullCPdataAndSave.m  now make more general
segmentFolder = '../MaySegmentation/output'
datadir= segmentFolder + '/*.h5' # 
output = glob2.glob(datadir)
output=sorted(output, key=lambda x:float(re.findall("(\d+)",x)[0]))
h5outname = segmentFolder + 'cp2020.h5'
sizeCut = 70 #only output trajectories longer than this parameter for MLE analysis

print output
traj=0
for i in output:

    X=loadh5(i)
    traj+=1
    length,pos,val = rle(X[:,-1])
    nsegsi=0
    for tx,leni in enumerate(length):
        if leni>sizeCut:
            segi=X[pos[tx]:pos[tx]+leni,0:-1] #truncate off the label info since routine expects frame,time,x,y info
            nsegsi+=1
            tagi=str(traj)+'_'+str(nsegsi)
            print('processing',i,tagi)
            wouth5(h5outname,segi,dset=tagi)
# Out:
# ['../MaySegmentation/output/1.h5', '../MaySegmentation/output/2.h5', '../MaySegmentation/output/3.h5', '../MaySegmentation/output/4.h5', '../MaySegmentation/output/5.h5', '../MaySegmentation/output/6.h5', '../MaySegmentation/output/7.h5', '../MaySegmentation/output/8.h5', '../MaySegmentation/output/9.h5', '../MaySegmentation/output/10.h5', '../MaySegmentation/output/11.h5', '../MaySegmentation/output/12.h5', '../MaySegmentation/output/13.h5', '../MaySegmentation/output/14.h5', '../MaySegmentation/output/15.h5', '../MaySegmentation/output/16.h5', '../MaySegmentation/output/17.h5', '../MaySegmentation/output/18.h5', '../MaySegmentation/output/19.h5', '../MaySegmentation/output/20.h5', '../MaySegmentation/output/21.h5', '../MaySegmentation/output/22.h5', '../MaySegmentation/output/23.h5', '../MaySegmentation/output/24.h5', '../MaySegmentation/output/25.h5', '../MaySegmentation/output/26.h5', '../MaySegmentation/output/27.h5', '../MaySegmentation/output/28.h5', '../MaySegmentation/output/29.h5', '../MaySegmentation/output/30.h5', '../MaySegmentation/output/31.h5', '../MaySegmentation/output/32.h5', '../MaySegmentation/output/33.h5', '../MaySegmentation/output/34.h5', '../MaySegmentation/output/35.h5', '../MaySegmentation/output/36.h5', '../MaySegmentation/output/37.h5', '../MaySegmentation/output/38.h5', '../MaySegmentation/output/39.h5', '../MaySegmentation/output/40.h5', '../MaySegmentation/output/41.h5', '../MaySegmentation/output/42.h5', '../MaySegmentation/output/43.h5', '../MaySegmentation/output/44.h5', '../MaySegmentation/output/45.h5', '../MaySegmentation/output/46.h5', '../MaySegmentation/output/47.h5', '../MaySegmentation/output/48.h5', '../MaySegmentation/output/49.h5', '../MaySegmentation/output/50.h5', '../MaySegmentation/output/51.h5', '../MaySegmentation/output/52.h5', '../MaySegmentation/output/53.h5', '../MaySegmentation/output/54.h5', '../MaySegmentation/output/55.h5', '../MaySegmentation/output/56.h5', '../MaySegmentation/output/57.h5', '../MaySegmentation/output/58.h5', '../MaySegmentation/output/59.h5', '../MaySegmentation/output/60.h5', '../MaySegmentation/output/61.h5', '../MaySegmentation/output/62.h5', '../MaySegmentation/output/63.h5', '../MaySegmentation/output/64.h5', '../MaySegmentation/output/65.h5', '../MaySegmentation/output/66.h5', '../MaySegmentation/output/67.h5', '../MaySegmentation/output/68.h5', '../MaySegmentation/output/69.h5', '../MaySegmentation/output/70.h5', '../MaySegmentation/output/71.h5', '../MaySegmentation/output/72.h5', '../MaySegmentation/output/73.h5', '../MaySegmentation/output/74.h5', '../MaySegmentation/output/75.h5', '../MaySegmentation/output/76.h5', '../MaySegmentation/output/77.h5', '../MaySegmentation/output/78.h5', '../MaySegmentation/output/79.h5', '../MaySegmentation/output/80.h5', '../MaySegmentation/output/81.h5', '../MaySegmentation/output/82.h5', '../MaySegmentation/output/83.h5', '../MaySegmentation/output/84.h5', '../MaySegmentation/output/85.h5', '../MaySegmentation/output/86.h5', '../MaySegmentation/output/87.h5', '../MaySegmentation/output/88.h5', '../MaySegmentation/output/89.h5', '../MaySegmentation/output/90.h5', '../MaySegmentation/output/91.h5', '../MaySegmentation/output/92.h5', '../MaySegmentation/output/93.h5', '../MaySegmentation/output/94.h5', '../MaySegmentation/output/95.h5', '../MaySegmentation/output/96.h5', '../MaySegmentation/output/97.h5', '../MaySegmentation/output/98.h5', '../MaySegmentation/output/99.h5', '../MaySegmentation/output/100.h5']
# ('processing', '../MaySegmentation/output/1.h5', '1_1')
# ('processing', '../MaySegmentation/output/1.h5', '1_2')
# ('processing', '../MaySegmentation/output/1.h5', '1_3')
# ('processing', '../MaySegmentation/output/2.h5', '2_1')
# ('processing', '../MaySegmentation/output/3.h5', '3_1')
# ('processing', '../MaySegmentation/output/3.h5', '3_2')
# ('processing', '../MaySegmentation/output/4.h5', '4_1')
# ('processing', '../MaySegmentation/output/4.h5', '4_2')
# ('processing', '../MaySegmentation/output/5.h5', '5_1')
# ('processing', '../MaySegmentation/output/6.h5', '6_1')
# ('processing', '../MaySegmentation/output/7.h5', '7_1')
# ('processing', '../MaySegmentation/output/8.h5', '8_1')
# ('processing', '../MaySegmentation/output/9.h5', '9_1')
# ('processing', '../MaySegmentation/output/10.h5', '10_1')
# ('processing', '../MaySegmentation/output/10.h5', '10_2')
# ('processing', '../MaySegmentation/output/10.h5', '10_3')
# ('processing', '../MaySegmentation/output/10.h5', '10_4')
# ('processing', '../MaySegmentation/output/11.h5', '11_1')
# ('processing', '../MaySegmentation/output/11.h5', '11_2')
# ('processing', '../MaySegmentation/output/12.h5', '12_1')
# ('processing', '../MaySegmentation/output/13.h5', '13_1')
# ('processing', '../MaySegmentation/output/14.h5', '14_1')
# ('processing', '../MaySegmentation/output/15.h5', '15_1')
# ('processing', '../MaySegmentation/output/15.h5', '15_2')
# ('processing', '../MaySegmentation/output/15.h5', '15_3')
# ('processing', '../MaySegmentation/output/16.h5', '16_1')
# ('processing', '../MaySegmentation/output/16.h5', '16_2')
# ('processing', '../MaySegmentation/output/16.h5', '16_3')
# ('processing', '../MaySegmentation/output/16.h5', '16_4')
# ('processing', '../MaySegmentation/output/17.h5', '17_1')
# ('processing', '../MaySegmentation/output/17.h5', '17_2')
# ('processing', '../MaySegmentation/output/18.h5', '18_1')
# ('processing', '../MaySegmentation/output/19.h5', '19_1')
# ('processing', '../MaySegmentation/output/19.h5', '19_2')
# ('processing', '../MaySegmentation/output/19.h5', '19_3')
# ('processing', '../MaySegmentation/output/19.h5', '19_4')
# ('processing', '../MaySegmentation/output/20.h5', '20_1')
# ('processing', '../MaySegmentation/output/21.h5', '21_1')
# ('processing', '../MaySegmentation/output/22.h5', '22_1')
# ('processing', '../MaySegmentation/output/23.h5', '23_1')
# ('processing', '../MaySegmentation/output/24.h5', '24_1')
# ('processing', '../MaySegmentation/output/24.h5', '24_2')
# ('processing', '../MaySegmentation/output/24.h5', '24_3')
# ('processing', '../MaySegmentation/output/25.h5', '25_1')
# ('processing', '../MaySegmentation/output/26.h5', '26_1')
# ('processing', '../MaySegmentation/output/26.h5', '26_2')
# ('processing', '../MaySegmentation/output/26.h5', '26_3')
# ('processing', '../MaySegmentation/output/27.h5', '27_1')
# ('processing', '../MaySegmentation/output/28.h5', '28_1')
# ('processing', '../MaySegmentation/output/28.h5', '28_2')
# ('processing', '../MaySegmentation/output/29.h5', '29_1')
# ('processing', '../MaySegmentation/output/30.h5', '30_1')
# ('processing', '../MaySegmentation/output/31.h5', '31_1')
# ('processing', '../MaySegmentation/output/32.h5', '32_1')
# ('processing', '../MaySegmentation/output/33.h5', '33_1')
# ('processing', '../MaySegmentation/output/34.h5', '34_1')
# ('processing', '../MaySegmentation/output/34.h5', '34_2')
# ('processing', '../MaySegmentation/output/35.h5', '35_1')
# ('processing', '../MaySegmentation/output/35.h5', '35_2')
# ('processing', '../MaySegmentation/output/35.h5', '35_3')
# ('processing', '../MaySegmentation/output/36.h5', '36_1')
# ('processing', '../MaySegmentation/output/36.h5', '36_2')
# ('processing', '../MaySegmentation/output/37.h5', '37_1')
# ('processing', '../MaySegmentation/output/37.h5', '37_2')
# ('processing', '../MaySegmentation/output/37.h5', '37_3')
# ('processing', '../MaySegmentation/output/37.h5', '37_4')
# ('processing', '../MaySegmentation/output/38.h5', '38_1')
# ('processing', '../MaySegmentation/output/39.h5', '39_1')
# ('processing', '../MaySegmentation/output/39.h5', '39_2')
# ('processing', '../MaySegmentation/output/40.h5', '40_1')
# ('processing', '../MaySegmentation/output/40.h5', '40_2')
# ('processing', '../MaySegmentation/output/40.h5', '40_3')
# ('processing', '../MaySegmentation/output/41.h5', '41_1')
# ('processing', '../MaySegmentation/output/41.h5', '41_2')
# ('processing', '../MaySegmentation/output/42.h5', '42_1')
# ('processing', '../MaySegmentation/output/42.h5', '42_2')
# ('processing', '../MaySegmentation/output/42.h5', '42_3')
# ('processing', '../MaySegmentation/output/43.h5', '43_1')
# ('processing', '../MaySegmentation/output/43.h5', '43_2')
# ('processing', '../MaySegmentation/output/43.h5', '43_3')
# ('processing', '../MaySegmentation/output/44.h5', '44_1')
# ('processing', '../MaySegmentation/output/45.h5', '45_1')
# ('processing', '../MaySegmentation/output/46.h5', '46_1')
# ('processing', '../MaySegmentation/output/46.h5', '46_2')
# ('processing', '../MaySegmentation/output/46.h5', '46_3')
# ('processing', '../MaySegmentation/output/47.h5', '47_1')
# ('processing', '../MaySegmentation/output/48.h5', '48_1')
# ('processing', '../MaySegmentation/output/49.h5', '49_1')
# ('processing', '../MaySegmentation/output/49.h5', '49_2')
# ('processing', '../MaySegmentation/output/50.h5', '50_1')
# ('processing', '../MaySegmentation/output/50.h5', '50_2')
# ('processing', '../MaySegmentation/output/51.h5', '51_1')
# ('processing', '../MaySegmentation/output/51.h5', '51_2')
# ('processing', '../MaySegmentation/output/52.h5', '52_1')
# ('processing', '../MaySegmentation/output/53.h5', '53_1')
# ('processing', '../MaySegmentation/output/54.h5', '54_1')
# ('processing', '../MaySegmentation/output/55.h5', '55_1')
# ('processing', '../MaySegmentation/output/55.h5', '55_2')
# ('processing', '../MaySegmentation/output/56.h5', '56_1')
# ('processing', '../MaySegmentation/output/56.h5', '56_2')
# ('processing', '../MaySegmentation/output/57.h5', '57_1')
# ('processing', '../MaySegmentation/output/58.h5', '58_1')
# ('processing', '../MaySegmentation/output/59.h5', '59_1')
# ('processing', '../MaySegmentation/output/60.h5', '60_1')
# ('processing', '../MaySegmentation/output/61.h5', '61_1')
# ('processing', '../MaySegmentation/output/61.h5', '61_2')
# ('processing', '../MaySegmentation/output/62.h5', '62_1')
# ('processing', '../MaySegmentation/output/62.h5', '62_2')
# ('processing', '../MaySegmentation/output/63.h5', '63_1')
# ('processing', '../MaySegmentation/output/63.h5', '63_2')
# ('processing', '../MaySegmentation/output/63.h5', '63_3')
# ('processing', '../MaySegmentation/output/64.h5', '64_1')
# ('processing', '../MaySegmentation/output/65.h5', '65_1')
# ('processing', '../MaySegmentation/output/65.h5', '65_2')
# ('processing', '../MaySegmentation/output/65.h5', '65_3')
# ('processing', '../MaySegmentation/output/66.h5', '66_1')
# ('processing', '../MaySegmentation/output/66.h5', '66_2')
# ('processing', '../MaySegmentation/output/67.h5', '67_1')
# ('processing', '../MaySegmentation/output/67.h5', '67_2')
# ('processing', '../MaySegmentation/output/68.h5', '68_1')
# ('processing', '../MaySegmentation/output/68.h5', '68_2')
# ('processing', '../MaySegmentation/output/69.h5', '69_1')
# ('processing', '../MaySegmentation/output/69.h5', '69_2')
# ('processing', '../MaySegmentation/output/70.h5', '70_1')
# ('processing', '../MaySegmentation/output/70.h5', '70_2')
# ('processing', '../MaySegmentation/output/71.h5', '71_1')
# ('processing', '../MaySegmentation/output/72.h5', '72_1')
# ('processing', '../MaySegmentation/output/72.h5', '72_2')
# ('processing', '../MaySegmentation/output/72.h5', '72_3')
# ('processing', '../MaySegmentation/output/73.h5', '73_1')
# ('processing', '../MaySegmentation/output/74.h5', '74_1')
# ('processing', '../MaySegmentation/output/75.h5', '75_1')
# ('processing', '../MaySegmentation/output/75.h5', '75_2')
# ('processing', '../MaySegmentation/output/76.h5', '76_1')
# ('processing', '../MaySegmentation/output/76.h5', '76_2')
# ('processing', '../MaySegmentation/output/76.h5', '76_3')
# ('processing', '../MaySegmentation/output/77.h5', '77_1')
# ('processing', '../MaySegmentation/output/78.h5', '78_1')
# ('processing', '../MaySegmentation/output/79.h5', '79_1')
# ('processing', '../MaySegmentation/output/80.h5', '80_1')
# ('processing', '../MaySegmentation/output/80.h5', '80_2')
# ('processing', '../MaySegmentation/output/80.h5', '80_3')
# ('processing', '../MaySegmentation/output/80.h5', '80_4')
# ('processing', '../MaySegmentation/output/80.h5', '80_5')
# ('processing', '../MaySegmentation/output/80.h5', '80_6')
# ('processing', '../MaySegmentation/output/80.h5', '80_7')
# ('processing', '../MaySegmentation/output/80.h5', '80_8')
# ('processing', '../MaySegmentation/output/80.h5', '80_9')
# ('processing', '../MaySegmentation/output/81.h5', '81_1')
# ('processing', '../MaySegmentation/output/81.h5', '81_2')
# ('processing', '../MaySegmentation/output/82.h5', '82_1')
# ('processing', '../MaySegmentation/output/83.h5', '83_1')
# ('processing', '../MaySegmentation/output/83.h5', '83_2')
# ('processing', '../MaySegmentation/output/84.h5', '84_1')
# ('processing', '../MaySegmentation/output/85.h5', '85_1')
# ('processing', '../MaySegmentation/output/86.h5', '86_1')
# ('processing', '../MaySegmentation/output/87.h5', '87_1')
# ('processing', '../MaySegmentation/output/88.h5', '88_1')
# ('processing', '../MaySegmentation/output/89.h5', '89_1')
# ('processing', '../MaySegmentation/output/89.h5', '89_2')
# ('processing', '../MaySegmentation/output/89.h5', '89_3')
# ('processing', '../MaySegmentation/output/90.h5', '90_1')
# ('processing', '../MaySegmentation/output/91.h5', '91_1')
# ('processing', '../MaySegmentation/output/92.h5', '92_1')
# ('processing', '../MaySegmentation/output/93.h5', '93_1')
# ('processing', '../MaySegmentation/output/94.h5', '94_1')
# ('processing', '../MaySegmentation/output/94.h5', '94_2')
# ('processing', '../MaySegmentation/output/95.h5', '95_1')
# ('processing', '../MaySegmentation/output/95.h5', '95_2')
# ('processing', '../MaySegmentation/output/95.h5', '95_3')
# ('processing', '../MaySegmentation/output/96.h5', '96_1')
# ('processing', '../MaySegmentation/output/96.h5', '96_2')
# ('processing', '../MaySegmentation/output/97.h5', '97_1')
# ('processing', '../MaySegmentation/output/98.h5', '98_1')
# ('processing', '../MaySegmentation/output/99.h5', '99_1')
# ('processing', '../MaySegmentation/output/99.h5', '99_2')
# ('processing', '../MaySegmentation/output/100.h5', '100_1')
# ('processing', '../MaySegmentation/output/100.h5', '100_2')
